# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import mmap
import random
import pickle
import os
import matplotlib.pyplot as plt
import math

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.set_float32_matmul_precision('high')


# CHANGED: n_layer 1->8, n_head 1->8, block_size 32->64, max_iters 1000->5000
# Bigger model = more capacity to learn patterns
block_size    = 128
batch_size    = 64
max_iters     = 18750
learning_rate = 3e-4
eval_iters    = 250
n_embd        = 384
n_layer       = 8
n_head        = 8
dropout       = 0.2

print(f'Device: {device}')
print(f'n_layer={n_layer} | n_head={n_head} | block_size={block_size} | max_iters={max_iters}')
# Out:
# Device: cuda
# n_layer=8 | n_head=8 | block_size=128 | max_iters=18750

# %%
import tiktoken
enc = tiktoken.get_encoding("gpt2")

vocab_size = enc.n_vocab  # 50257
encode = lambda s: enc.encode(s, allowed_special={'<|endoftext|>'})
decode = lambda l: enc.decode(l)

print(f"Vocab size: {vocab_size}")
# Out:
# Vocab size: 50257

# %%
def get_random_chunk(split):
    filename = 'output_train.txt' if split == 'train' else 'output_val.txt'
    with open(filename, 'rb') as f:
        with mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ) as mm:
            file_size = len(mm)
            while True:  # ← keep trying until we get a big enough chunk
                start_pos = random.randint(0, file_size - block_size * batch_size)
                mm.seek(start_pos)
                block = mm.read(block_size * batch_size - 1)
                decoded_block = block.decode('utf-8', errors='ignore')
                data = torch.tensor(encode(decoded_block), dtype=torch.long)
                if len(data) > block_size + batch_size:  # ← only return if big enough
                    return data

def get_batch(split):
    data = get_random_chunk(split)
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x.to(device), y.to(device)

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key   = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * k.shape[-1]**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        return wei @ self.value(x)


class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads   = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj    = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        return self.dropout(self.proj(out))


class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        # CHANGED: ReLU -> GELU (modern standard, performs better in transformers)
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)


class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa   = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1  = nn.LayerNorm(n_embd)
        self.ln2  = nn.LayerNorm(n_embd)

    def forward(self, x):
        # CHANGED: Pre-LayerNorm - normalize BEFORE attention, more stable training
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class GPTLanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table    = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks  = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f    = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, index, targets=None):
        B, T = index.shape
        tok_emb = self.token_embedding_table(index)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = self.blocks(tok_emb + pos_emb)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            B, T, C = logits.shape
            loss = F.cross_entropy(logits.view(B*T, C), targets.view(B*T))
        return logits, loss

    def generate(self, index, max_new_tokens):
        for _ in range(max_new_tokens):
            index_cond = index[:, -block_size:]
            logits, _ = self.forward(index_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            index_next = torch.multinomial(probs, num_samples=1)
            index = torch.cat((index, index_next), dim=1)
        return index


# CHANGED: checks if pkl exists before loading, starts fresh if not
model = GPTLanguageModel(vocab_size)
if os.path.exists('model-best.pkl'):
    print('Loading best model...')
    with open('model-best.pkl', 'rb') as f:
        model = pickle.load(f)
    print('Loaded successfully - continuing from step ~1250')
else:
    print('Starting fresh')

m = model.to(device)

m = model.to(device)
print(f'Parameters: {sum(p.numel() for p in m.parameters()):,}')
# Out:
# Loading best model...
# Loaded successfully - continuing from step ~1250
# Parameters: 52,884,049

# %%
optimizer     = torch.optim.AdamW(model.parameters(), lr=learning_rate)
best_val_loss = float('inf')

# Track losses for plotting
train_losses = []
val_losses   = []
loss_steps   = []

def get_lr(it):
    warmup_iters = 100
    min_lr = learning_rate / 10
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    decay = (it - warmup_iters) / (max_iters - warmup_iters)
    return min_lr + 0.5 * (learning_rate - min_lr) * (1 + math.cos(math.pi * decay))

for iter in range(max_iters):
    # Apply learning rate schedule
    lr = get_lr(iter)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    if iter % eval_iters == 0:
        losses = estimate_loss()
        print(f'step {iter:5d} | train: {losses["train"]:.4f} | val: {losses["val"]:.4f} | lr: {lr:.6f}')
        train_losses.append(losses['train'].item())
        val_losses.append(losses['val'].item())
        loss_steps.append(iter)

        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            with open('model-best.pkl', 'wb') as f:
                pickle.dump(model, f)
            print(f'  -> new best saved (val: {best_val_loss:.4f})')

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    optimizer.step()

print(f'\nFinal loss: {loss.item():.4f}')
with open('model-01.pkl', 'wb') as f:
    pickle.dump(model, f)
print('Model saved!')
# Out:
# step     0 | train: 6.0188 | val: 6.0566 | lr: 0.000000
#   -> new best saved (val: 6.0566)
# step   250 | train: 6.0112 | val: 6.0467 | lr: 0.000300
#   -> new best saved (val: 6.0467)
# step   500 | train: 5.9673 | val: 5.9940 | lr: 0.000300
#   -> new best saved (val: 5.9940)
# step   750 | train: 5.8668 | val: 5.9192 | lr: 0.000299
#   -> new best saved (val: 5.9192)
# step  1000 | train: 5.7578 | val: 5.7880 | lr: 0.000298
#   -> new best saved (val: 5.7880)
# step  1250 | train: 5.7149 | val: 5.7306 | lr: 0.000297
#   -> new best saved (val: 5.7306)
# step  1500 | train: 5.7125 | val: 5.7233 | lr: 0.000296
#   -> new best saved (val: 5.7233)
# step  1750 | train: 5.6378 | val: 5.7182 | lr: 0.000295
#   -> new best saved (val: 5.7182)
# step  2000 | train: 5.5978 | val: 5.6777 | lr: 0.000293
#   -> new best saved (val: 5.6777)
# step  2250 | train: 5.5521 | val: 5.5792 | lr: 0.000291
#   -> new best saved (val: 5.5792)
# step  2500 | train: 5.4963 | val: 5.5546 | lr: 0.000289
#   -> new best saved (val: 5.5546)
# step  2750 | train: 5.4853 | val: 5.5305 | lr: 0.000287
#   -> new best saved (val: 5.5305)
# step  3000 | train: 5.4504 | val: 5.4802 | lr: 0.000284
#   -> new best saved (val: 5.4802)
# step  3250 | train: 5.4353 | val: 5.4196 | lr: 0.000281
#   -> new best saved (val: 5.4196)
# step  3500 | train: 5.3825 | val: 5.3876 | lr: 0.000278
#   -> new best saved (val: 5.3876)
# step  3750 | train: 5.3739 | val: 5.3576 | lr: 0.000275
#   -> new best saved (val: 5.3576)
# step  4000 | train: 5.3388 | val: 5.3473 | lr: 0.000272
#   -> new best saved (val: 5.3473)
# step  4250 | train: 5.3253 | val: 5.3777 | lr: 0.000268
# step  4500 | train: 5.3219 | val: 5.2730 | lr: 0.000265
#   -> new best saved (val: 5.2730)
# step  4750 | train: 5.3370 | val: 5.2765 | lr: 0.000261
# step  5000 | train: 5.2730 | val: 5.2518 | lr: 0.000257
#   -> new best saved (val: 5.2518)
# step  5250 | train: 5.2519 | val: 5.2825 | lr: 0.000252
# step  5500 | train: 5.2336 | val: 5.2349 | lr: 0.000248
#   -> new best saved (val: 5.2349)
# step  5750 | train: 5.1848 | val: 5.2402 | lr: 0.000243
# step  6000 | train: 5.1920 | val: 5.1781 | lr: 0.000239
#   -> new best saved (val: 5.1781)
# step  6250 | train: 5.1198 | val: 5.1550 | lr: 0.000234
#   -> new best saved (val: 5.1550)
# step  6500 | train: 5.2167 | val: 5.1819 | lr: 0.000229
# step  6750 | train: 5.1620 | val: 5.1381 | lr: 0.000224
#   -> new best saved (val: 5.1381)
# step  7000 | train: 5.1402 | val: 5.1249 | lr: 0.000219
#   -> new best saved (val: 5.1249)
# step  7250 | train: 5.0994 | val: 5.0516 | lr: 0.000213
#   -> new best saved (val: 5.0516)
# step  7500 | train: 5.0563 | val: 5.1227 | lr: 0.000208
# step  7750 | train: 5.0315 | val: 5.0763 | lr: 0.000203
# step  8000 | train: 5.0766 | val: 5.0510 | lr: 0.000197
#   -> new best saved (val: 5.0510)
# step  8250 | train: 5.0239 | val: 5.0041 | lr: 0.000192
#   -> new best saved (val: 5.0041)
# step  8500 | train: 5.0385 | val: 5.0598 | lr: 0.000186
# step  8750 | train: 5.0318 | val: 4.9987 | lr: 0.000180
#   -> new best saved (val: 4.9987)
# step  9000 | train: 4.9739 | val: 5.0188 | lr: 0.000175
# step  9250 | train: 4.9675 | val: 5.0358 | lr: 0.000169
# step  9500 | train: 5.0023 | val: 4.9760 | lr: 0.000163
#   -> new best saved (val: 4.9760)
# step  9750 | train: 4.9574 | val: 5.0207 | lr: 0.000158
# step 10000 | train: 4.9615 | val: 4.8973 | lr: 0.000152
#   -> new best saved (val: 4.8973)
# step 10250 | train: 4.9485 | val: 4.9687 | lr: 0.000146
# step 10500 | train: 4.9758 | val: 4.9547 | lr: 0.000141
# step 10750 | train: 4.9400 | val: 4.9259 | lr: 0.000135
# step 11000 | train: 4.9319 | val: 5.0173 | lr: 0.000130
# step 11250 | train: 4.9259 | val: 4.8652 | lr: 0.000124
#   -> new best saved (val: 4.8652)
# step 11500 | train: 4.9228 | val: 4.9356 | lr: 0.000119
# step 11750 | train: 4.8912 | val: 4.8837 | lr: 0.000113
# step 12000 | train: 4.8667 | val: 4.8824 | lr: 0.000108
# step 12250 | train: 4.8083 | val: 4.8314 | lr: 0.000103
#   -> new best saved (val: 4.8314)
# step 12500 | train: 4.8526 | val: 4.8750 | lr: 0.000098
# step 12750 | train: 4.8288 | val: 4.8275 | lr: 0.000093
#   -> new best saved (val: 4.8275)
# step 13000 | train: 4.8689 | val: 4.8680 | lr: 0.000089
# step 13250 | train: 4.8626 | val: 4.8318 | lr: 0.000084
# step 13500 | train: 4.8644 | val: 4.8617 | lr: 0.000079
# step 13750 | train: 4.8817 | val: 4.8318 | lr: 0.000075
# step 14000 | train: 4.8213 | val: 4.7927 | lr: 0.000071
#   -> new best saved (val: 4.7927)
# step 14250 | train: 4.7938 | val: 4.7794 | lr: 0.000067
#   -> new best saved (val: 4.7794)
# step 14500 | train: 4.7852 | val: 4.8108 | lr: 0.000063
# step 14750 | train: 4.8195 | val: 4.8015 | lr: 0.000060
# step 15000 | train: 4.7888 | val: 4.7243 | lr: 0.000056
#   -> new best saved (val: 4.7243)
# step 15250 | train: 4.8201 | val: 4.7864 | lr: 0.000053
# step 15500 | train: 4.7952 | val: 4.7423 | lr: 0.000050
# step 15750 | train: 4.7696 | val: 4.7556 | lr: 0.000047
# step 16000 | train: 4.7355 | val: 4.7823 | lr: 0.000044
# step 16250 | train: 4.7791 | val: 4.8113 | lr: 0.000042
# step 16500 | train: 4.7344 | val: 4.7796 | lr: 0.000040
# step 16750 | train: 4.7482 | val: 4.8079 | lr: 0.000038
# step 17000 | train: 4.7471 | val: 4.7579 | lr: 0.000036
# step 17250 | train: 4.7698 | val: 4.7666 | lr: 0.000034
# step 17500 | train: 4.7606 | val: 4.7650 | lr: 0.000033
# step 17750 | train: 4.7522 | val: 4.7629 | lr: 0.000032
# step 18000 | train: 4.7660 | val: 4.7302 | lr: 0.000031
# step 18250 | train: 4.6852 | val: 4.7402 | lr: 0.000030
# step 18500 | train: 4.7576 | val: 4.7542 | lr: 0.000030
#
# Final loss: 4.9690
# Model saved!

# %%
# NEW: plot loss curve to visualize training progress
plt.figure(figsize=(10, 5))
plt.plot(loss_steps, train_losses, label='Train loss')
plt.plot(loss_steps, val_losses,   label='Val loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig('loss_curve.png')
plt.show()
print('Loss curve saved to loss_curve.png')
# Out:
# Loss curve saved to loss_curve.png

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated_chars = decode(m.generate(context, max_new_tokens=500)[0].tolist())
print(generated_chars)
# Out:
# ! Another past since I commented on that are dealing with the quality of greatness or purpose behind me. Slasher created
#
# We heard after watching's fight, but we were also about immediate treatment as a cause ofacha imperative. Word erupted down, but more freedom listening to the ugly metastatic creations realized perfectly. Right?
#
# Be aware the Eastersheet' His De Eugene presentza
#
# Over the years the Orasard, who briefly pledged that conspiracy to support the meaning, gave a theological eyes, saying "--------------- aren't after anything, [the destruction of business liberty] to defend Jeremy signing in fighting the truth about it … exists on internet budget so it has a lot better moment of hearing about the story at my thoughts sharing when the parties are declared [ stupidityunning you] if [ hurts] and vaco, we will be glad it's a liberal advance partially optional.
#
# Next to this article post some stating: That is totally understandable.
#
# One of the inner world's most famous references from the wider successes of the progressive view of new polls is that Page To Check out an approach here.
#
# During more than a warning agreement, it follows that the Senate was taking the process (specifically) to the enthusiastic US elections and the United States vote. The major change has not skipped
#
# These IS's fantastic campaign may be reminiscent of the polls across small nations, throughout the country, or embrace the fact that the bill on March 29, has been preparing to cross about four of the top dissoration of the former president's presidential reduction in income.
#
# Please may answer documents on Tuesday when Facebook eliminated its again in the European but also asked by next week's selection an announcementricocene bomb abuse for official requests. 10 days coverage on Sept. 23, 2017. NBC Wings admitted its changes with former Greg Christie supporters of many former House presidential candidate Donald practiceers Walker, African-American and populist adviser Cliffie feed with the Brit, who are among the top women and Carlson, who has never dropped from the foreclosure of AFP. collapsed under the a bill that gave fuel to the federal government and violated the First Amendment capital in its support. The donor warned that the highest-payment rate of theormarian quarter of foreign banks regulator would opt or increase in disruption.
#
# Taylor John DeMach insisted he had more in stock and darker shares than any other population
