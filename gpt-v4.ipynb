# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import mmap
import random
import pickle
import os
import matplotlib.pyplot as plt
import math

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.set_float32_matmul_precision('high')


# CHANGED: n_layer 1->8, n_head 1->8, block_size 32->64, max_iters 1000->5000
# Bigger model = more capacity to learn patterns
block_size    = 128
batch_size    = 64
max_iters     = 20000
learning_rate = 3e-4
eval_iters    = 100
n_embd        = 384
n_layer       = 8
n_head        = 8
dropout       = 0.2

print(f'Device: {device}')
print(f'n_layer={n_layer} | n_head={n_head} | block_size={block_size} | max_iters={max_iters}')
# Out:
# Device: cuda
# n_layer=8 | n_head=8 | block_size=128 | max_iters=20000

# %%
import tiktoken
enc = tiktoken.get_encoding("gpt2")

vocab_size = enc.n_vocab  # 50257
encode = lambda s: enc.encode(s, allowed_special={'<|endoftext|>'})
decode = lambda l: enc.decode(l)

print(f"Vocab size: {vocab_size}")
# Out:
# Vocab size: 50257

# %%
def get_random_chunk(split):
    filename = 'output_train.txt' if split == 'train' else 'output_val.txt'
    with open(filename, 'rb') as f:
        with mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ) as mm:
            file_size = len(mm)
            while True:  # ← keep trying until we get a big enough chunk
                start_pos = random.randint(0, file_size - block_size * batch_size)
                mm.seek(start_pos)
                block = mm.read(block_size * batch_size - 1)
                decoded_block = block.decode('utf-8', errors='ignore')
                data = torch.tensor(encode(decoded_block), dtype=torch.long)
                if len(data) > block_size + batch_size:  # ← only return if big enough
                    return data

def get_batch(split):
    data = get_random_chunk(split)
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x.to(device), y.to(device)

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key   = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * k.shape[-1]**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        return wei @ self.value(x)


class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads   = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj    = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        return self.dropout(self.proj(out))


class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        # CHANGED: ReLU -> GELU (modern standard, performs better in transformers)
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)


class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa   = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1  = nn.LayerNorm(n_embd)
        self.ln2  = nn.LayerNorm(n_embd)

    def forward(self, x):
        # CHANGED: Pre-LayerNorm - normalize BEFORE attention, more stable training
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class GPTLanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table    = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks  = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f    = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size, bias=False)  # ← add bias=False
        
        self.token_embedding_table.weight = self.lm_head.weight  # ← before apply
        
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, index, targets=None):
        B, T = index.shape
        tok_emb = self.token_embedding_table(index)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = self.blocks(tok_emb + pos_emb)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            B, T, C = logits.shape
            loss = F.cross_entropy(logits.view(B*T, C), targets.view(B*T))
        return logits, loss

    def generate(self, index, max_new_tokens, temperature=0.8, top_k=40):
        for _ in range(max_new_tokens):
            index_cond = index[:, -block_size:]
            logits, _ = self.forward(index_cond)
            logits = logits[:, -1, :] / temperature
            v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
            logits[logits < v[:, [-1]]] = float('-inf')
            probs = F.softmax(logits, dim=-1)
            index_next = torch.multinomial(probs, num_samples=1)
            index = torch.cat((index, index_next), dim=1)
        return index


# CHANGED: checks if pkl exists before loading, starts fresh if not
model = GPTLanguageModel(vocab_size)
if os.path.exists('model-best.pkl'):
    print('Loading best model...')
    with open('model-best.pkl', 'rb') as f:
        model = pickle.load(f)
    print('Loaded successfully - continuing from step ~1250')
else:
    print('Starting fresh')

m = model.to(device)
print(f'Parameters: {sum(p.numel() for p in m.parameters()):,}')
# Out:
# Starting fresh
# Parameters: 33,535,104

# %%
optimizer     = torch.optim.AdamW(model.parameters(), lr=learning_rate)
scaler        = torch.amp.GradScaler('cuda')

best_val_loss = float('inf')
train_losses  = []
val_losses    = []
loss_steps    = []

def get_lr(it):
    warmup_iters = 100
    min_lr = learning_rate / 10
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    decay = (it - warmup_iters) / (max_iters - warmup_iters)
    return min_lr + 0.5 * (learning_rate - min_lr) * (1 + math.cos(math.pi * decay))

for iter in range(max_iters):
    lr = get_lr(iter)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    if iter % eval_iters == 0:
        losses = estimate_loss()
        print(f'step {iter:5d} | train: {losses["train"]:.4f} | val: {losses["val"]:.4f} | lr: {lr:.6f}')
        
        train_losses.append(losses['train'].item())
        val_losses.append(losses['val'].item())
        loss_steps.append(iter)

        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            with open('model-best.pkl', 'wb') as f:
                pickle.dump(model, f)
            print(f'  -> new best saved (val: {best_val_loss:.4f})')

    xb, yb = get_batch('train')

    # CHANGED: mixed precision training
    with torch.amp.autocast('cuda'):
        logits, loss = model(xb, yb)

    optimizer.zero_grad(set_to_none=True)
    scaler.scale(loss).backward()
    scaler.unscale_(optimizer)
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    scaler.step(optimizer)
    scaler.update()

print(f'\nFinal loss: {loss.item():.4f}')
with open('model-01.pkl', 'wb') as f:
    pickle.dump(model, f)
print('Model saved!')
# Out:
# step     0 | train: 10.8965 | val: 10.8980 | lr: 0.000000
#   -> new best saved (val: 10.8980)
# step   100 | train: 7.2603 | val: 7.3518 | lr: 0.000300
#   -> new best saved (val: 7.3518)
# step   200 | train: 6.9111 | val: 6.9506 | lr: 0.000300
#   -> new best saved (val: 6.9506)
# step   300 | train: 6.6591 | val: 6.6800 | lr: 0.000300
#   -> new best saved (val: 6.6800)
# step   400 | train: 6.5506 | val: 6.5786 | lr: 0.000300
#   -> new best saved (val: 6.5786)
# step   500 | train: 6.5039 | val: 6.3644 | lr: 0.000300
#   -> new best saved (val: 6.3644)
# step   600 | train: 6.4902 | val: 6.3632 | lr: 0.000300
#   -> new best saved (val: 6.3632)
# step   700 | train: 6.3431 | val: 6.3936 | lr: 0.000299
# step   800 | train: 6.3218 | val: 6.2790 | lr: 0.000299
#   -> new best saved (val: 6.2790)
# step   900 | train: 6.1952 | val: 6.2417 | lr: 0.000299
#   -> new best saved (val: 6.2417)
# step  1000 | train: 6.3177 | val: 6.1561 | lr: 0.000299
#   -> new best saved (val: 6.1561)
# step  1100 | train: 6.2245 | val: 6.0618 | lr: 0.000298
#   -> new best saved (val: 6.0618)
# step  1200 | train: 6.2058 | val: 6.1386 | lr: 0.000298
# step  1300 | train: 6.0683 | val: 6.0648 | lr: 0.000298
# step  1400 | train: 6.1254 | val: 6.0527 | lr: 0.000297
#   -> new best saved (val: 6.0527)
# step  1500 | train: 6.0803 | val: 6.0313 | lr: 0.000297
#   -> new best saved (val: 6.0313)
# step  1600 | train: 5.9602 | val: 5.9726 | lr: 0.000296
#   -> new best saved (val: 5.9726)
# step  1700 | train: 5.9437 | val: 5.8829 | lr: 0.000296
#   -> new best saved (val: 5.8829)
# step  1800 | train: 5.9152 | val: 5.9146 | lr: 0.000295
# step  1900 | train: 5.8754 | val: 5.8396 | lr: 0.000295
#   -> new best saved (val: 5.8396)
# step  2000 | train: 5.7945 | val: 5.8899 | lr: 0.000294
# step  2100 | train: 5.8058 | val: 5.7925 | lr: 0.000293
#   -> new best saved (val: 5.7925)
# step  2200 | train: 5.8074 | val: 5.8294 | lr: 0.000293
# step  2300 | train: 5.7769 | val: 5.7736 | lr: 0.000292
#   -> new best saved (val: 5.7736)
# step  2400 | train: 5.7636 | val: 5.7413 | lr: 0.000291
#   -> new best saved (val: 5.7413)
# step  2500 | train: 5.6911 | val: 5.7173 | lr: 0.000290
#   -> new best saved (val: 5.7173)
# step  2600 | train: 5.6431 | val: 5.6979 | lr: 0.000290
#   -> new best saved (val: 5.6979)
# step  2700 | train: 5.7125 | val: 5.6643 | lr: 0.000289
#   -> new best saved (val: 5.6643)
# step  2800 | train: 5.6860 | val: 5.6324 | lr: 0.000288
#   -> new best saved (val: 5.6324)
# step  2900 | train: 5.6079 | val: 5.6519 | lr: 0.000287
# step  3000 | train: 5.5973 | val: 5.5509 | lr: 0.000286
#   -> new best saved (val: 5.5509)
# step  3100 | train: 5.5205 | val: 5.5309 | lr: 0.000285
#   -> new best saved (val: 5.5309)
# step  3200 | train: 5.6315 | val: 5.6296 | lr: 0.000284
# step  3300 | train: 5.5779 | val: 5.5648 | lr: 0.000283
# step  3400 | train: 5.5295 | val: 5.5329 | lr: 0.000282
# step  3500 | train: 5.4878 | val: 5.5799 | lr: 0.000281
# step  3600 | train: 5.5029 | val: 5.5480 | lr: 0.000280
# step  3700 | train: 5.5448 | val: 5.5012 | lr: 0.000279
#   -> new best saved (val: 5.5012)
# step  3800 | train: 5.5008 | val: 5.5943 | lr: 0.000278
# step  3900 | train: 5.5114 | val: 5.4790 | lr: 0.000276
#   -> new best saved (val: 5.4790)
# step  4000 | train: 5.5030 | val: 5.4903 | lr: 0.000275
# step  4100 | train: 5.4638 | val: 5.4559 | lr: 0.000274
#   -> new best saved (val: 5.4559)
# step  4200 | train: 5.4122 | val: 5.4448 | lr: 0.000273
#   -> new best saved (val: 5.4448)
# step  4300 | train: 5.4700 | val: 5.4539 | lr: 0.000271
# step  4400 | train: 5.4571 | val: 5.3855 | lr: 0.000270
#   -> new best saved (val: 5.3855)
# step  4500 | train: 5.3736 | val: 5.4499 | lr: 0.000269
# step  4600 | train: 5.3587 | val: 5.3607 | lr: 0.000267
#   -> new best saved (val: 5.3607)
# step  4700 | train: 5.4045 | val: 5.3326 | lr: 0.000266
#   -> new best saved (val: 5.3326)
# step  4800 | train: 5.3367 | val: 5.3106 | lr: 0.000265
#   -> new best saved (val: 5.3106)
# step  4900 | train: 5.3797 | val: 5.3574 | lr: 0.000263
# step  5000 | train: 5.3183 | val: 5.3734 | lr: 0.000262
# step  5100 | train: 5.3198 | val: 5.3699 | lr: 0.000260
# step  5200 | train: 5.3506 | val: 5.3490 | lr: 0.000259
# step  5300 | train: 5.3583 | val: 5.2313 | lr: 0.000257
#   -> new best saved (val: 5.2313)
# step  5400 | train: 5.3134 | val: 5.2865 | lr: 0.000255
# step  5500 | train: 5.3379 | val: 5.2824 | lr: 0.000254
# step  5600 | train: 5.2483 | val: 5.3101 | lr: 0.000252
# step  5700 | train: 5.2150 | val: 5.2378 | lr: 0.000251
# step  5800 | train: 5.2515 | val: 5.2367 | lr: 0.000249
# step  5900 | train: 5.2535 | val: 5.2562 | lr: 0.000247
# step  6000 | train: 5.2625 | val: 5.2442 | lr: 0.000246
# step  6100 | train: 5.2726 | val: 5.3612 | lr: 0.000244
# step  6200 | train: 5.2981 | val: 5.2732 | lr: 0.000242
# step  6300 | train: 5.2870 | val: 5.2046 | lr: 0.000240
#   -> new best saved (val: 5.2046)
# step  6400 | train: 5.2786 | val: 5.1536 | lr: 0.000239
#   -> new best saved (val: 5.1536)
# step  6500 | train: 5.1367 | val: 5.1838 | lr: 0.000237
# step  6600 | train: 5.1926 | val: 5.1770 | lr: 0.000235
# step  6700 | train: 5.2440 | val: 5.2794 | lr: 0.000233
# step  6800 | train: 5.1864 | val: 5.2079 | lr: 0.000231
# step  6900 | train: 5.1728 | val: 5.1848 | lr: 0.000229
# step  7000 | train: 5.2148 | val: 5.2107 | lr: 0.000228
# step  7100 | train: 5.1726 | val: 5.0832 | lr: 0.000226
#   -> new best saved (val: 5.0832)
# step  7200 | train: 5.1062 | val: 5.2463 | lr: 0.000224
# step  7300 | train: 5.1060 | val: 5.1065 | lr: 0.000222
# step  7400 | train: 5.1588 | val: 5.1315 | lr: 0.000220
# step  7500 | train: 5.2392 | val: 5.2321 | lr: 0.000218
# step  7600 | train: 5.1228 | val: 5.0787 | lr: 0.000216
#   -> new best saved (val: 5.0787)
# step  7700 | train: 5.1576 | val: 5.1268 | lr: 0.000214
# step  7800 | train: 5.0989 | val: 5.1585 | lr: 0.000212
# step  7900 | train: 5.1411 | val: 5.1394 | lr: 0.000210
# step  8000 | train: 5.0887 | val: 5.1504 | lr: 0.000208
# step  8100 | train: 5.1672 | val: 5.1176 | lr: 0.000206
# step  8200 | train: 5.0823 | val: 5.0896 | lr: 0.000204
# step  8300 | train: 5.0499 | val: 5.1109 | lr: 0.000202
# step  8400 | train: 5.0931 | val: 5.0391 | lr: 0.000200
#   -> new best saved (val: 5.0391)
# step  8500 | train: 5.0659 | val: 5.1067 | lr: 0.000198
# step  8600 | train: 5.0789 | val: 5.1058 | lr: 0.000196
# step  8700 | train: 5.0431 | val: 4.9767 | lr: 0.000194
#   -> new best saved (val: 4.9767)
# step  8800 | train: 5.0184 | val: 5.0695 | lr: 0.000191
# step  8900 | train: 5.0863 | val: 5.0932 | lr: 0.000189
# step  9000 | train: 5.0605 | val: 5.0067 | lr: 0.000187
# step  9100 | train: 5.0846 | val: 5.0500 | lr: 0.000185
# step  9200 | train: 4.9718 | val: 5.0960 | lr: 0.000183
# step  9300 | train: 5.0734 | val: 5.0822 | lr: 0.000181
# step  9400 | train: 4.9793 | val: 5.0461 | lr: 0.000179
# step  9500 | train: 4.9730 | val: 5.0242 | lr: 0.000177
# step  9600 | train: 5.0266 | val: 5.0889 | lr: 0.000175
# step  9700 | train: 5.0418 | val: 5.0080 | lr: 0.000172
# step  9800 | train: 5.0075 | val: 4.9837 | lr: 0.000170
# step  9900 | train: 4.9574 | val: 4.9727 | lr: 0.000168
#   -> new best saved (val: 4.9727)
# step 10000 | train: 4.9706 | val: 4.9543 | lr: 0.000166
#   -> new best saved (val: 4.9543)
# step 10100 | train: 4.9169 | val: 5.0425 | lr: 0.000164
# step 10200 | train: 5.0166 | val: 4.9381 | lr: 0.000162
#   -> new best saved (val: 4.9381)
# step 10300 | train: 4.9833 | val: 4.9391 | lr: 0.000160
# step 10400 | train: 5.0452 | val: 5.0565 | lr: 0.000158
# step 10500 | train: 4.9517 | val: 5.0053 | lr: 0.000155
# step 10600 | train: 4.9512 | val: 4.9982 | lr: 0.000153
# step 10700 | train: 4.9601 | val: 4.9252 | lr: 0.000151
#   -> new best saved (val: 4.9252)
# step 10800 | train: 4.9891 | val: 4.9682 | lr: 0.000149
# step 10900 | train: 4.9037 | val: 4.9624 | lr: 0.000147
# step 11000 | train: 5.0010 | val: 5.0141 | lr: 0.000145
# step 11100 | train: 5.0238 | val: 4.9481 | lr: 0.000143
# step 11200 | train: 4.9850 | val: 4.9673 | lr: 0.000141
# step 11300 | train: 4.9744 | val: 4.8932 | lr: 0.000139
#   -> new best saved (val: 4.8932)
# step 11400 | train: 4.9077 | val: 4.8961 | lr: 0.000136
# step 11500 | train: 4.9372 | val: 4.9675 | lr: 0.000134
# step 11600 | train: 4.9309 | val: 4.9011 | lr: 0.000132
# step 11700 | train: 4.9535 | val: 4.9033 | lr: 0.000130
# step 11800 | train: 4.9325 | val: 4.9491 | lr: 0.000128
# step 11900 | train: 4.9081 | val: 4.9249 | lr: 0.000126
# step 12000 | train: 4.9207 | val: 4.8714 | lr: 0.000124
#   -> new best saved (val: 4.8714)
# step 12100 | train: 4.9226 | val: 4.9490 | lr: 0.000122
# step 12200 | train: 4.8946 | val: 4.9160 | lr: 0.000120
# step 12300 | train: 4.9033 | val: 4.9157 | lr: 0.000118
# step 12400 | train: 4.8520 | val: 4.9329 | lr: 0.000116
# step 12500 | train: 4.8756 | val: 4.8932 | lr: 0.000114
# step 12600 | train: 4.8952 | val: 4.8508 | lr: 0.000112
#   -> new best saved (val: 4.8508)
# step 12700 | train: 4.9012 | val: 4.8855 | lr: 0.000110
# step 12800 | train: 4.8665 | val: 4.9057 | lr: 0.000108
# step 12900 | train: 4.8833 | val: 4.9437 | lr: 0.000106
# step 13000 | train: 4.8466 | val: 4.8450 | lr: 0.000104
#   -> new best saved (val: 4.8450)
# step 13100 | train: 4.8738 | val: 4.8397 | lr: 0.000102
#   -> new best saved (val: 4.8397)
# step 13200 | train: 4.8855 | val: 4.8569 | lr: 0.000101
# step 13300 | train: 4.8295 | val: 4.9114 | lr: 0.000099
# step 13400 | train: 4.8033 | val: 4.8414 | lr: 0.000097
# step 13500 | train: 4.7770 | val: 4.8501 | lr: 0.000095
# step 13600 | train: 4.8588 | val: 4.8579 | lr: 0.000093
# step 13700 | train: 4.8505 | val: 4.9448 | lr: 0.000091
# step 13800 | train: 4.8587 | val: 4.8500 | lr: 0.000090
# step 13900 | train: 4.8581 | val: 4.8983 | lr: 0.000088
# step 14000 | train: 4.9451 | val: 4.8332 | lr: 0.000086
#   -> new best saved (val: 4.8332)
# step 14100 | train: 4.8758 | val: 4.8457 | lr: 0.000084
# step 14200 | train: 4.8689 | val: 4.9086 | lr: 0.000083
# step 14300 | train: 4.8462 | val: 4.7873 | lr: 0.000081
#   -> new best saved (val: 4.7873)
# step 14400 | train: 4.8302 | val: 4.8173 | lr: 0.000079
# step 14500 | train: 4.8695 | val: 4.8150 | lr: 0.000078
# step 14600 | train: 4.8057 | val: 4.8129 | lr: 0.000076
# step 14700 | train: 4.8192 | val: 4.7484 | lr: 0.000075
#   -> new best saved (val: 4.7484)
# step 14800 | train: 4.8710 | val: 4.8549 | lr: 0.000073
# step 14900 | train: 4.8645 | val: 4.8098 | lr: 0.000071
# step 15000 | train: 4.7895 | val: 4.8611 | lr: 0.000070
# step 15100 | train: 4.7923 | val: 4.7699 | lr: 0.000068
# step 15200 | train: 4.7199 | val: 4.8677 | lr: 0.000067
# step 15300 | train: 4.9009 | val: 4.7737 | lr: 0.000065
# step 15400 | train: 4.8388 | val: 4.8006 | lr: 0.000064
# step 15500 | train: 4.8457 | val: 4.7919 | lr: 0.000063
# step 15600 | train: 4.7545 | val: 4.8029 | lr: 0.000061
# step 15700 | train: 4.7840 | val: 4.8929 | lr: 0.000060
# step 15800 | train: 4.6995 | val: 4.7972 | lr: 0.000059
# step 15900 | train: 4.8071 | val: 4.8118 | lr: 0.000057
# step 16000 | train: 4.7834 | val: 4.7800 | lr: 0.000056
# step 16100 | train: 4.7601 | val: 4.8092 | lr: 0.000055
# step 16200 | train: 4.7689 | val: 4.8046 | lr: 0.000054
# step 16300 | train: 4.8181 | val: 4.7588 | lr: 0.000052
# step 16400 | train: 4.7875 | val: 4.8365 | lr: 0.000051
# step 16500 | train: 4.8248 | val: 4.7545 | lr: 0.000050
# step 16600 | train: 4.7942 | val: 4.8366 | lr: 0.000049
# step 16700 | train: 4.7441 | val: 4.7701 | lr: 0.000048
# step 16800 | train: 4.7622 | val: 4.8327 | lr: 0.000047
# step 16900 | train: 4.7346 | val: 4.7514 | lr: 0.000046
# step 17000 | train: 4.7953 | val: 4.7218 | lr: 0.000045
#   -> new best saved (val: 4.7218)
# step 17100 | train: 4.7752 | val: 4.7662 | lr: 0.000044
# step 17200 | train: 4.8219 | val: 4.7503 | lr: 0.000043
# step 17300 | train: 4.7616 | val: 4.7817 | lr: 0.000042
# step 17400 | train: 4.7123 | val: 4.7993 | lr: 0.000041
# step 17500 | train: 4.7837 | val: 4.7448 | lr: 0.000040
# step 17600 | train: 4.8156 | val: 4.8933 | lr: 0.000040
# step 17700 | train: 4.8253 | val: 4.7345 | lr: 0.000039
# step 17800 | train: 4.7608 | val: 4.7205 | lr: 0.000038
#   -> new best saved (val: 4.7205)
# step 17900 | train: 4.7381 | val: 4.7406 | lr: 0.000037
# step 18000 | train: 4.7997 | val: 4.8017 | lr: 0.000037
# step 18100 | train: 4.7375 | val: 4.6842 | lr: 0.000036
#   -> new best saved (val: 4.6842)
# step 18200 | train: 4.7408 | val: 4.7164 | lr: 0.000035
# step 18300 | train: 4.8288 | val: 4.7144 | lr: 0.000035
# step 18400 | train: 4.7771 | val: 4.7549 | lr: 0.000034
# step 18500 | train: 4.7635 | val: 4.7906 | lr: 0.000034
# step 18600 | train: 4.7251 | val: 4.7756 | lr: 0.000033
# step 18700 | train: 4.7155 | val: 4.7466 | lr: 0.000033
# step 18800 | train: 4.7342 | val: 4.7399 | lr: 0.000032
# step 18900 | train: 4.7579 | val: 4.7311 | lr: 0.000032
# step 19000 | train: 4.7958 | val: 4.7782 | lr: 0.000032
# step 19100 | train: 4.8399 | val: 4.7644 | lr: 0.000031
# step 19200 | train: 4.7322 | val: 4.7536 | lr: 0.000031
# step 19300 | train: 4.7918 | val: 4.7285 | lr: 0.000031
# step 19400 | train: 4.8026 | val: 4.7270 | lr: 0.000031
# step 19500 | train: 4.7321 | val: 4.8090 | lr: 0.000030
# step 19600 | train: 4.7889 | val: 4.7592 | lr: 0.000030
# step 19700 | train: 4.6999 | val: 4.8206 | lr: 0.000030
# step 19800 | train: 4.6740 | val: 4.7927 | lr: 0.000030
# step 19900 | train: 4.8090 | val: 4.7833 | lr: 0.000030
#
# Final loss: 4.6546
# Model saved!

# %%
# NEW: plot loss curve to visualize training progress
plt.figure(figsize=(10, 5))
plt.plot(loss_steps, train_losses, label='Train loss')
plt.plot(loss_steps, val_losses,   label='Val loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig('loss_curve.png')
plt.show()
print('Loss curve saved to loss_curve.png')
# Out:
# Loss curve saved to loss_curve.png

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated = decode(m.generate(context, max_new_tokens=500, temperature=0.8, top_k=40)[0].tolist())
print(generated)
# Out:
# !
#
# In April, of the study conducted by the International Times from the Institute for Environmental Energy Research, the University of America, and the Environmental Protection Agency (ICP) in the United States. The first, first-generation, French scientist and author of the Science Institute, was the bestseller for the Institute of Research and Research, and the first time a company's research was to work in a new study from the American Science Society.
#
# In a group of patients with the University of Michigan, a handful of students and college students were among the schools at the University of California at the University of California.
#
# The study includes a University of California-based, a University of California, and a group of students. The study also included a group of students in the area of the United States, and has been employed by the University of California, in the University of California, California.
#
# The study also includes a variety of students who are the best women with a friend. “You can choose one of the five children, and you’ll find a teacher that is one of these years with a child in the city.”
#
# This is the same method for a woman who is the University of Chicago, said her mother, a woman, and a person as a child, is in a child’s.
#
# As such as a female school student, she’s a school professor and the student. She wants to make a child better.
#
# “I know her and her father have been with so much as many as the school’s and her daughter’s family, because she’s going to get her to work for her,” she says. “She’s going to have to work with the children at home.”
#
# He said she never left her, and she has said her wife was in a public health school.
#
# “I’m happy when I’m.”
#
# She says she’s not just sitting in it – but not to make it in her right, but she has always made their way back to the community. “He was very proud to be in the city, I’m very happy,” she also said. “He’s always right. My
